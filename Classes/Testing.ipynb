# %%
from BoardSquare import BoardSquare
from ChessPiece import ChessPiece
from ChessBoard import ChessBoard
from ChessSet import ChessSet
from Player import Player

# %%
game1 = ChessSet()

# %%
game1.play(20)
# Out:
# Turn Number: 0
#     ---------------------------------
# 8   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
# 7   | P | P | P | P | P | P | P | P |
#     ---------------------------------
# 6   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 5   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 4   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 3   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 2   | P | P | P | P | P | P | P | P |
#     ---------------------------------
# 1   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
#
#       a   b   c   d   e   f   g   h
# White plays Pe2 to e4
# Turn Number: 1
#     ---------------------------------
# 8   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
# 7   | P | P | P | P | P | P | P | P |
#     ---------------------------------
# 6   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 5   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 4   |   |   |   |   | P |   |   |   |
#     ---------------------------------
# 3   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 2   | P | P | P | P |   | P | P | P |
#     ---------------------------------
# 1   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
#
#       a   b   c   d   e   f   g   h
#
#
#
#
#
#
# Black plays Pe7 to e5
# Turn Number: 2
#     ---------------------------------
# 8   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
# 7   | P | P | P | P |   | P | P | P |
#     ---------------------------------
# 6   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 5   |   |   |   |   | P |   |   |   |
#     ---------------------------------
# 4   |   |   |   |   | P |   |   |   |
#     ---------------------------------
# 3   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 2   | P | P | P | P |   | P | P | P |
#     ---------------------------------
# 1   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
#
#       a   b   c   d   e   f   g   h
#
#
#
#
#
#
# White plays Pd2 to d4
# Turn Number: 3
#     ---------------------------------
# 8   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
# 7   | P | P | P | P |   | P | P | P |
#     ---------------------------------
# 6   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 5   |   |   |   |   | P |   |   |   |
#     ---------------------------------
# 4   |   |   |   | P | P |   |   |   |
#     ---------------------------------
# 3   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 2   | P | P | P |   |   | P | P | P |
#     ---------------------------------
# 1   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
#
#       a   b   c   d   e   f   g   h
#
#
#
#
#
#
# Black plays Pd7 to d5
# Turn Number: 4
#     ---------------------------------
# 8   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
# 7   | P | P | P |   |   | P | P | P |
#     ---------------------------------
# 6   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 5   |   |   |   | P | P |   |   |   |
#     ---------------------------------
# 4   |   |   |   | P | P |   |   |   |
#     ---------------------------------
# 3   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 2   | P | P | P |   |   | P | P | P |
#     ---------------------------------
# 1   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
#
#       a   b   c   d   e   f   g   h
#
#
#
#
#
#
# White plays Pd4 to e5
# Captured piece uID: 21
#
# Turn Number: 5
#     ---------------------------------
# 8   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
# 7   | P | P | P |   |   | P | P | P |
#     ---------------------------------
# 6   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 5   |   |   |   | P | P |   |   |   |
#     ---------------------------------
# 4   |   |   |   |   | P |   |   |   |
#     ---------------------------------
# 3   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 2   | P | P | P |   |   | P | P | P |
#     ---------------------------------
# 1   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
#
#       a   b   c   d   e   f   g   h
#
#
#
#
#
#
# Black plays Pd5 to e4
# Captured piece uID: 13
#
# Turn Number: 6
#     ---------------------------------
# 8   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
# 7   | P | P | P |   |   | P | P | P |
#     ---------------------------------
# 6   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 5   |   |   |   |   | P |   |   |   |
#     ---------------------------------
# 4   |   |   |   |   | P |   |   |   |
#     ---------------------------------
# 3   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 2   | P | P | P |   |   | P | P | P |
#     ---------------------------------
# 1   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
#
#       a   b   c   d   e   f   g   h
#
#
#
#
#
#
# White plays Qd1 to d8
# Captured piece uID: 28
#
# Turn Number: 7
#     ---------------------------------
# 8   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
# 7   | P | P | P |   |   | P | P | P |
#     ---------------------------------
# 6   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 5   |   |   |   |   | P |   |   |   |
#     ---------------------------------
# 4   |   |   |   |   | P |   |   |   |
#     ---------------------------------
# 3   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 2   | P | P | P |   |   | P | P | P |
#     ---------------------------------
# 1   | R | N | B |   | K | B | N | R |
#     ---------------------------------
#
#       a   b   c   d   e   f   g   h
#
#
#
#
#
#
# Black plays Pa7 to a5
# Turn Number: 8
#     ---------------------------------
# 8   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
# 7   |   | P | P |   |   | P | P | P |
#     ---------------------------------
# 6   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 5   | P |   |   |   | P |   |   |   |
#     ---------------------------------
# 4   |   |   |   |   | P |   |   |   |
#     ---------------------------------
# 3   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 2   | P | P | P |   |   | P | P | P |
#     ---------------------------------
# 1   | R | N | B |   | K | B | N | R |
#     ---------------------------------
#
#       a   b   c   d   e   f   g   h
#
#
#
#
#
#
# White plays Qd8 to e8
# Captured piece uID: 29
#
# Turn Number: 9
#     ---------------------------------
# 8   | R | N | B |   | Q | B | N | R |
#     ---------------------------------
# 7   |   | P | P |   |   | P | P | P |
#     ---------------------------------
# 6   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 5   | P |   |   |   | P |   |   |   |
#     ---------------------------------
# 4   |   |   |   |   | P |   |   |   |
#     ---------------------------------
# 3   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 2   | P | P | P |   |   | P | P | P |
#     ---------------------------------
# 1   | R | N | B |   | K | B | N | R |
#     ---------------------------------
#
#       a   b   c   d   e   f   g   h
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-ae6668e18188> in <module>
# ----> 1 game1.play(20)
#
# ~/Projects/SearchingForBottyFischer/Classes/ChessSet.py in play(self, num_moves)
#      51                 pm = self.player2.gen_pseudolegal_moves(self.player2.color_num,self.CB)
#      52                 #print(f'Player 2 pseudolegal moves: {pm}\n')
# ---> 53                 lm = self.player2.check_legality(self.player2.color_num,pm,self.CB)
#      54                 for moves in lm.values():
#      55                     for move in moves:
#
# ~/Projects/SearchingForBottyFischer/Classes/Player.py in check_legality(self, c, possible_moves, CB)
#      75                 tmp_CB.Board.update({f'{move}': BoardSquare(f'{move}', CB.Board[f'{start_sq}'].occupant_id, tmp_CB.Board[f'{move}'].sq_potential-1,CB.Board[f'{start_sq}'].occupant_uID)})
#      76                 tmp_CB.Board.update({f'{start_sq}': BoardSquare(f'{start_sq}', 0, tmp_CB.Board[f'{start_sq}'].sq_potential+1, 0)})
# ---> 77                 if not self.is_King_in_check(self.color_num,tmp_CB):
#      78                     lms_per_piece.append(move)
#      79                     #print(f'piece: {piece}\nmove: {move}\nself.CB_threat_and_supports: {self.board_threat_and_supports}\ntmp_board_threat_and_supports: {tmp_board_threat_and_supports}\nbts_diff: {bts_diff}\n')
#
# ~/Projects/SearchingForBottyFischer/Classes/Player.py in is_King_in_check(self, c, CB)
#      89         #print(f'board: {board}\n')
#      90         rev_board = {o.occupant_id: sq for sq,o in CB.Board.items()}
# ---> 91         king_pos = rev_board[6*c]
#      92         opponent_moves = self.gen_pseudolegal_moves(-c,CB)
#      93         in_check = False
#
# KeyError: -6
