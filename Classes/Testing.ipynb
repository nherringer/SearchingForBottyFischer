# %%
from BoardSquare import BoardSquare
from ChessPiece import ChessPiece
from ChessBoard import ChessBoard
from ChessSet import ChessSet
from Player import Player

# %%
game1 = ChessSet()
# Out:
# Turn Number: 0
#     ---------------------------------
# 8   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
# 7   | P | P | P | P | P | P | P | P |
#     ---------------------------------
# 6   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 5   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 4   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 3   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 2   | P | P | P | P | P | P | P | P |
#     ---------------------------------
# 1   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
#
#       a   b   c   d   e   f   g   h

# %%
game1.play(12)
# Out:
# White lm_pressure:, {'b1': ['c3', 'a3', 'd2'], 'g1': ['h3', 'f3', 'e2'], 'a2': ['b3'], 'b2': ['a3', 'c3'], 'c2': ['b3', 'd3'], 'd2': ['c3', 'e3'], 'e2': ['d3', 'f3'], 'f2': ['e3', 'g3'], 'g2': ['f3', 'h3'], 'h2': ['g3']}
#
# Player White moves piece uID 12 from d2 to d4
# Turn Number: 1
#     ---------------------------------
# 8   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
# 7   | P | P | P | P | P | P | P | P |
#     ---------------------------------
# 6   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 5   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 4   |   |   |   | P |   |   |   |   |
#     ---------------------------------
# 3   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 2   | P | P | P |   | P | P | P | P |
#     ---------------------------------
# 1   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
#
#       a   b   c   d   e   f   g   h
#
#
#
#
#
#
# Black lm_pressure:, {'a7': ['b6'], 'b7': ['c6', 'a6'], 'c7': ['d6', 'b6'], 'd7': ['e6', 'c6'], 'e7': ['f6', 'd6'], 'f7': ['g6', 'e6'], 'g7': ['h6', 'f6'], 'h7': ['g6'], 'b8': ['c6', 'a6', 'd7'], 'g8': ['h6', 'f6', 'e7']}
#
# Player Black moves piece uID 20 from d7 to d5
# Turn Number: 2
#     ---------------------------------
# 8   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
# 7   | P | P | P |   | P | P | P | P |
#     ---------------------------------
# 6   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 5   |   |   |   | P |   |   |   |   |
#     ---------------------------------
# 4   |   |   |   | P |   |   |   |   |
#     ---------------------------------
# 3   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 2   | P | P | P |   | P | P | P | P |
#     ---------------------------------
# 1   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
#
#       a   b   c   d   e   f   g   h
#
#
#
#
#
#
# White lm_pressure:, {'b1': ['c3', 'a3', 'd2'], 'c1': ['d2', 'e3', 'f4', 'g5', 'h6', 'b2'], 'd1': ['e1', 'c1', 'd2', 'd3', 'd4'], 'e1': ['f2', 'f1', 'e2', 'e1', 'd2', 'd1'], 'g1': ['h3', 'f3', 'e2'], 'a2': ['b3'], 'b2': ['a3', 'c3'], 'c2': ['b3', 'd3'], 'e2': ['d3', 'f3'], 'f2': ['e3', 'g3'], 'g2': ['f3', 'h3'], 'h2': ['g3']}
#
# Player White moves piece uID 13 from e2 to e4
# Turn Number: 3
#     ---------------------------------
# 8   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
# 7   | P | P | P |   | P | P | P | P |
#     ---------------------------------
# 6   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 5   |   |   |   | P |   |   |   |   |
#     ---------------------------------
# 4   |   |   |   | P | P |   |   |   |
#     ---------------------------------
# 3   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 2   | P | P | P |   |   | P | P | P |
#     ---------------------------------
# 1   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
#
#       a   b   c   d   e   f   g   h
#
#
#
#
#
#
# Black lm_pressure:, {'a7': ['b6'], 'b7': ['c6', 'a6'], 'c7': ['d6', 'b6'], 'd5': ['e4', 'c4'], 'e7': ['f6', 'd6'], 'f7': ['g6', 'e6'], 'g7': ['h6', 'f6'], 'h7': ['g6'], 'b8': ['c6', 'a6', 'd7'], 'c8': ['b7', 'd7', 'e6', 'f5', 'g4', 'h3'], 'd8': ['c8', 'e8', 'd7', 'd6', 'd5'], 'e8': ['f8', 'f7', 'e8', 'e7', 'd8', 'd7'], 'g8': ['h6', 'f6', 'e7']}
#
# Player Black moves piece uID 20 from d5 to e4
# Turn Number: 4
#     ---------------------------------
# 8   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
# 7   | P | P | P |   | P | P | P | P |
#     ---------------------------------
# 6   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 5   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 4   |   |   |   | P | P |   |   |   |
#     ---------------------------------
# 3   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 2   | P | P | P |   |   | P | P | P |
#     ---------------------------------
# 1   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
#
#       a   b   c   d   e   f   g   h
#
#
#
#
#
#
# White lm_pressure:, {'b1': ['c3', 'a3', 'd2'], 'c1': ['d2', 'e3', 'f4', 'g5', 'h6', 'b2'], 'd1': ['e1', 'c1', 'd2', 'd3', 'd4', 'e2', 'f3', 'g4', 'h5', 'c2'], 'e1': ['f2', 'f1', 'e2', 'e1', 'd2', 'd1'], 'f1': ['g2', 'e2', 'd3', 'c4', 'b5', 'a6'], 'g1': ['h3', 'f3', 'e2'], 'a2': ['b3'], 'b2': ['a3', 'c3'], 'c2': ['b3', 'd3'], 'd4': ['c5', 'e5'], 'f2': ['e3', 'g3'], 'g2': ['f3', 'h3'], 'h2': ['g3']}
#
# Player White moves piece uID 9 from a2 to a4
# Turn Number: 5
#     ---------------------------------
# 8   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
# 7   | P | P | P |   | P | P | P | P |
#     ---------------------------------
# 6   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 5   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 4   | P |   |   | P | P |   |   |   |
#     ---------------------------------
# 3   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 2   |   | P | P |   |   | P | P | P |
#     ---------------------------------
# 1   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
#
#       a   b   c   d   e   f   g   h
#
#
#
#
#
#
# Black lm_pressure:, {'a7': ['b6'], 'b7': ['c6', 'a6'], 'c7': ['d6', 'b6'], 'e4': ['f3', 'd3'], 'e7': ['f6', 'd6'], 'f7': ['g6', 'e6'], 'g7': ['h6', 'f6'], 'h7': ['g6'], 'b8': ['c6', 'a6', 'd7'], 'c8': ['b7', 'd7', 'e6', 'f5', 'g4', 'h3'], 'd8': ['c8', 'e8', 'd7', 'd6', 'd5', 'd4'], 'e8': ['f8', 'f7', 'e8', 'e7', 'd8', 'd7'], 'g8': ['h6', 'f6', 'e7']}
#
# Player Black moves piece uID 28 from d8 to d4
# Turn Number: 6
#     ---------------------------------
# 8   | R | N | B |   | K | B | N | R |
#     ---------------------------------
# 7   | P | P | P |   | P | P | P | P |
#     ---------------------------------
# 6   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 5   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 4   | P |   |   | Q | P |   |   |   |
#     ---------------------------------
# 3   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 2   |   | P | P |   |   | P | P | P |
#     ---------------------------------
# 1   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
#
#       a   b   c   d   e   f   g   h
#
#
#
#
#
#
# White lm_pressure:, {'a1': ['b1', 'a2', 'a3', 'a4'], 'b1': ['c3', 'a3', 'd2'], 'c1': ['d2', 'e3', 'f4', 'g5', 'h6', 'b2'], 'd1': ['e1', 'c1', 'd2', 'd3', 'd4', 'e2', 'f3', 'g4', 'h5', 'c2'], 'e1': ['f2', 'f1', 'e2', 'e1', 'd2', 'd1'], 'f1': ['g2', 'e2', 'd3', 'c4', 'b5', 'a6'], 'g1': ['h3', 'f3', 'e2'], 'a4': ['b5'], 'b2': ['a3', 'c3'], 'c2': ['b3', 'd3'], 'f2': ['e3', 'g3'], 'g2': ['f3', 'h3'], 'h2': ['g3']}
#
# Player White moves piece uID 10 from b2 to b4
# Turn Number: 7
#     ---------------------------------
# 8   | R | N | B |   | K | B | N | R |
#     ---------------------------------
# 7   | P | P | P |   | P | P | P | P |
#     ---------------------------------
# 6   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 5   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 4   | P | P |   | Q | P |   |   |   |
#     ---------------------------------
# 3   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 2   |   |   | P |   |   | P | P | P |
#     ---------------------------------
# 1   | R | N | B | Q | K | B | N | R |
#     ---------------------------------
#
#       a   b   c   d   e   f   g   h
#
#
#
#
#
#
# Black lm_pressure:, {'a7': ['b6'], 'b7': ['c6', 'a6'], 'c7': ['d6', 'b6'], 'e4': ['f3', 'd3'], 'e7': ['f6', 'd6'], 'f7': ['g6', 'e6'], 'g7': ['h6', 'f6'], 'h7': ['g6'], 'b8': ['c6', 'a6', 'd7'], 'c8': ['b7', 'd7', 'e6', 'f5', 'g4', 'h3'], 'd4': ['c4', 'b4', 'e4', 'd3', 'd2', 'd1', 'd5', 'd6', 'd7', 'd8', 'c3', 'b2', 'a1', 'e3', 'f2', 'c5', 'b6', 'a7', 'e5', 'f6', 'g7'], 'e8': ['f8', 'f7', 'e8', 'e7', 'd8', 'd7'], 'g8': ['h6', 'f6', 'e7']}
#
# Player Black moves piece uID 28 from d4 to a1
# Turn Number: 8
#     ---------------------------------
# 8   | R | N | B |   | K | B | N | R |
#     ---------------------------------
# 7   | P | P | P |   | P | P | P | P |
#     ---------------------------------
# 6   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 5   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 4   | P | P |   |   | P |   |   |   |
#     ---------------------------------
# 3   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 2   |   |   | P |   |   | P | P | P |
#     ---------------------------------
# 1   | Q | N | B | Q | K | B | N | R |
#     ---------------------------------
#
#       a   b   c   d   e   f   g   h
# White lm_pressure:, {'b1': ['c3', 'a3', 'd2'], 'c1': ['d2', 'e3', 'f4', 'g5', 'h6', 'b2', 'a3'], 'd1': ['e1', 'c1', 'd2', 'd3', 'd4', 'd5', 'd6', 'd7', 'd8', 'e2', 'f3', 'g4', 'h5', 'c2'], 'e1': ['f2', 'f1', 'e2', 'e1', 'd2', 'd1'], 'f1': ['g2', 'e2', 'd3', 'c4', 'b5', 'a6'], 'g1': ['h3', 'f3', 'e2'], 'a4': ['b5'], 'b4': ['a5', 'c5'], 'c2': ['b3', 'd3'], 'f2': ['e3', 'g3'], 'g2': ['f3', 'h3'], 'h2': ['g3']}
#
# Player White moves piece uID 16 from h2 to h4
# Turn Number: 9
#     ---------------------------------
# 8   | R | N | B |   | K | B | N | R |
#     ---------------------------------
# 7   | P | P | P |   | P | P | P | P |
#     ---------------------------------
# 6   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 5   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 4   | P | P |   |   | P |   |   | P |
#     ---------------------------------
# 3   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 2   |   |   | P |   |   | P | P |   |
#     ---------------------------------
# 1   | Q | N | B | Q | K | B | N | R |
#     ---------------------------------
#
#       a   b   c   d   e   f   g   h
#
#
#
#
#
#
# Black lm_pressure:, {'a7': ['b6'], 'b7': ['c6', 'a6'], 'c7': ['d6', 'b6'], 'e4': ['f3', 'd3'], 'e7': ['f6', 'd6'], 'f7': ['g6', 'e6'], 'g7': ['h6', 'f6'], 'h7': ['g6'], 'b8': ['c6', 'a6', 'd7'], 'c8': ['b7', 'd7', 'e6', 'f5', 'g4', 'h3'], 'a1': ['b1', 'a2', 'a3', 'a4', 'b2', 'c3', 'd4', 'e5', 'f6', 'g7'], 'e8': ['f8', 'f7', 'e8', 'e7', 'd8', 'd7'], 'g8': ['h6', 'f6', 'e7']}
#
# Player Black moves piece uID 28 from a1 to b1
# Turn Number: 10
#     ---------------------------------
# 8   | R | N | B |   | K | B | N | R |
#     ---------------------------------
# 7   | P | P | P |   | P | P | P | P |
#     ---------------------------------
# 6   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 5   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 4   | P | P |   |   | P |   |   | P |
#     ---------------------------------
# 3   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 2   |   |   | P |   |   | P | P |   |
#     ---------------------------------
# 1   |   | Q | B | Q | K | B | N | R |
#     ---------------------------------
#
#       a   b   c   d   e   f   g   h
#
#
#
#
#
#
# White lm_pressure:, {'c1': ['d2', 'e3', 'f4', 'g5', 'h6', 'b2', 'a3'], 'd1': ['e1', 'c1', 'd2', 'd3', 'd4', 'd5', 'd6', 'd7', 'd8', 'e2', 'f3', 'g4', 'h5', 'c2'], 'e1': ['f2', 'f1', 'e2', 'e1', 'd2', 'd1'], 'f1': ['g2', 'e2', 'd3', 'c4', 'b5', 'a6'], 'g1': ['h3', 'f3', 'e2'], 'h1': ['g1', 'h2', 'h3', 'h4'], 'a4': ['b5'], 'b4': ['a5', 'c5'], 'c2': ['b3', 'd3'], 'f2': ['e3', 'g3'], 'g2': ['f3', 'h3'], 'h4': ['g5']}
#
# Player White moves piece uID 6 from f1 to a6
# Turn Number: 11
#     ---------------------------------
# 8   | R | N | B |   | K | B | N | R |
#     ---------------------------------
# 7   | P | P | P |   | P | P | P | P |
#     ---------------------------------
# 6   | B |   |   |   |   |   |   |   |
#     ---------------------------------
# 5   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 4   | P | P |   |   | P |   |   | P |
#     ---------------------------------
# 3   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 2   |   |   | P |   |   | P | P |   |
#     ---------------------------------
# 1   |   | Q | B | Q | K |   | N | R |
#     ---------------------------------
#
#       a   b   c   d   e   f   g   h
#
#
#
#
#
#
# Black lm_pressure:, {'b7': ['c6', 'a6'], 'c7': ['d6', 'b6'], 'e4': ['f3', 'd3'], 'e7': ['f6', 'd6'], 'f7': ['g6', 'e6'], 'g7': ['h6', 'f6'], 'h7': ['g6'], 'b8': ['c6', 'a6', 'd7'], 'c8': ['b7', 'd7', 'e6', 'f5', 'g4', 'h3'], 'b1': ['a1', 'c1', 'b2', 'b3', 'b4', 'a2', 'c2'], 'e8': ['f8', 'f7', 'e8', 'e7', 'd8', 'd7'], 'g8': ['h6', 'f6', 'e7']}
#
# Player Black moves piece uID 18 from b7 to a6
# Turn Number: 12
#     ---------------------------------
# 8   | R | N | B |   | K | B | N | R |
#     ---------------------------------
# 7   | P |   | P |   | P | P | P | P |
#     ---------------------------------
# 6   | P |   |   |   |   |   |   |   |
#     ---------------------------------
# 5   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 4   | P | P |   |   | P |   |   | P |
#     ---------------------------------
# 3   |   |   |   |   |   |   |   |   |
#     ---------------------------------
# 2   |   |   | P |   |   | P | P |   |
#     ---------------------------------
# 1   |   | Q | B | Q | K |   | N | R |
#     ---------------------------------
#
#       a   b   c   d   e   f   g   h
